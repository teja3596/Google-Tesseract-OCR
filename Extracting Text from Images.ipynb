# %%
import pytesseract

# %%
img1 = plt.imread('quotes.jpg')

plt.imshow(img1)

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files (x86)\Tesseract-OCR\tesseract'

# %%
print(pytesseract.image_to_string('quotes.jpg'))
# Out:
# If you’re always
# tryingto be normal
# you will never know
# how amazing you can be.
#
# - Maya Angelou
#
# §oo1|cost
